# %%
from transformers import AutoTokenizer, AutoModel
from bertviz import head_view, neuron_view

# %%
tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
model = AutoModel.from_pretrained("openai-community/gpt2")
# Out:
# /Users/tonimo/git/teaching-networks/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
sentence = "Which sounds better for breakfast, pancakes, eggs, or cereal?"
inputs = tokenizer.encode(sentence, return_tensors="pt", add_special_tokens=True)
outputs = model(inputs, output_attentions=True)
attention = outputs[-1]
tokens = [tokenizer.decode(inid, skip_special_tokens=False) for inid in inputs[0]]

# %%
head_view(attention, tokens)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-251fda27e34848c6b7973f9cb521e181" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
